# %%
taxas_operadoras = {
'STONE': {
    'txs_mdr': {
        '1':  {'VISA': 2.59, 'MASTERCARD': 2.59, 'AMEX': 2.59, 'CABAL': 5, 'HYPERCARD': 2.59, 'UNIONPAY': 4, 'ELO': 2.59},
        '2':  {'VISA': 2.59, 'MASTERCARD': 2.59, 'AMEX': 2.59, 'CABAL': 5.25, 'HYPERCARD': 2.59, 'UNIONPAY': 4, 'ELO': 2.59},
        '3':  {'VISA': 2.59, 'MASTERCARD': 2.59, 'AMEX': 2.59, 'CABAL': 5.25, 'HYPERCARD': 2.59, 'UNIONPAY': 4, 'ELO': 2.59},
        '4':  {'VISA': 2.59, 'MASTERCARD': 2.59, 'AMEX': 2.59, 'CABAL': 5.25, 'HYPERCARD': 2.59, 'UNIONPAY': 4, 'ELO': 2.59},
        '5':  {'VISA': 2.59, 'MASTERCARD': 2.59, 'AMEX': 2.59, 'CABAL': 5.25, 'HYPERCARD': 2.59, 'UNIONPAY': 4, 'ELO': 2.59},
        '6':  {'VISA': 2.59, 'MASTERCARD': 2.59, 'AMEX': 2.59, 'CABAL': 5.25, 'HYPERCARD': 2.59, 'UNIONPAY': 4, 'ELO': 2.59},
        '7':  {'VISA': 2.63, 'MASTERCARD': 2.63, 'AMEX': 2.59, 'CABAL': 5.5, 'HYPERCARD': 2.59, 'UNIONPAY': 4, 'ELO': 2.59},
        '8':  {'VISA': 2.63, 'MASTERCARD': 2.63, 'AMEX': 2.59, 'CABAL': 5.5, 'HYPERCARD': 2.59, 'UNIONPAY': 4, 'ELO': 2.59},
        '9':  {'VISA': 2.63, 'MASTERCARD': 2.63, 'AMEX': 2.59, 'CABAL': 5.5, 'HYPERCARD': 2.59, 'UNIONPAY': 4, 'ELO': 2.59},
        '10': {'VISA': 2.63, 'MASTERCARD': 2.63, 'AMEX': 2.59, 'CABAL': 5.5, 'HYPERCARD': 2.59, 'UNIONPAY': 4, 'ELO': 2.59},
        '11': {'VISA': 2.63, 'MASTERCARD': 2.63, 'AMEX': 2.59, 'CABAL': 5.5, 'HYPERCARD': 2.59, 'UNIONPAY': 4, 'ELO': 2.59},
        '12': {'VISA': 2.63, 'MASTERCARD': 2.63, 'AMEX': 2.59, 'CABAL': 5.5, 'HYPERCARD': 2.59, 'UNIONPAY': 4, 'ELO': 2.59},
        '13': {'VISA': 2.59, 'MASTERCARD': 2.59, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 2.59},
        '14': {'VISA': 2.59, 'MASTERCARD': 2.59, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 2.59},
        '15': {'VISA': 2.59, 'MASTERCARD': 2.59, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 2.59},
        '16': {'VISA': 2.59, 'MASTERCARD': 2.59, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 2.59},
        '17': {'VISA': 2.59, 'MASTERCARD': 2.59, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 2.59},
        '18': {'VISA': 2.59, 'MASTERCARD': 2.59, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 2.59},
                 },
    'txs_antecipacao': {
        '1':  {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': 1.85, 'CABAL': 1.85, 'HYPERCARD': 1.85, 'UNIONPAY': 1.85, 'ELO': 1.85},
        '2':  {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': 1.85, 'CABAL': 1.85, 'HYPERCARD': 1.85, 'UNIONPAY': 1.85, 'ELO': 1.85},
        '3':  {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': 1.85, 'CABAL': 1.85, 'HYPERCARD': 1.85, 'UNIONPAY': 1.85, 'ELO': 1.85},
        '4':  {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': 1.85, 'CABAL': 1.85, 'HYPERCARD': 1.85, 'UNIONPAY': 1.85, 'ELO': 1.85},
        '5':  {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': 1.85, 'CABAL': 1.85, 'HYPERCARD': 1.85, 'UNIONPAY': 1.85, 'ELO': 1.85},
        '6':  {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': 1.85, 'CABAL': 1.85, 'HYPERCARD': 1.85, 'UNIONPAY': 1.85, 'ELO': 1.85},
        '7':  {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': 1.85, 'CABAL': 1.85, 'HYPERCARD': 1.85, 'UNIONPAY': 1.85, 'ELO': 1.85},
        '8':  {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': 1.85, 'CABAL': 1.85, 'HYPERCARD': 1.85, 'UNIONPAY': 1.85, 'ELO': 1.85},
        '9':  {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': 1.85, 'CABAL': 1.85, 'HYPERCARD': 1.85, 'UNIONPAY': 1.85, 'ELO': 1.85},
        '10': {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': 1.85, 'CABAL': 1.85, 'HYPERCARD': 1.85, 'UNIONPAY': 1.85, 'ELO': 1.85},
        '11': {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': 1.85, 'CABAL': 1.85, 'HYPERCARD': 1.85, 'UNIONPAY': 1.85, 'ELO': 1.85},
        '12': {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': 1.85, 'CABAL': 1.85, 'HYPERCARD': 1.85, 'UNIONPAY': 1.85, 'ELO': 1.85},
        '13': {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 1.85},
        '14': {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 1.85},
        '15': {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 1.85},
        '16': {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 1.85},
        '17': {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 1.85},
        '18': {'VISA': 1.85, 'MASTERCARD': 1.85, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 1.85},
                 },
         },

'BLU': {
    'txs_mdr': {
        '1':  {'VISA': 1.99, 'MASTERCARD': 1.99, 'AMEX': 3.49, 'HYPERCARD': 3.49, 'ELO': 3.49},
        '2':  {'VISA': 2.29, 'MASTERCARD': 2.29, 'AMEX': 3.79, 'HYPERCARD': 3.79, 'ELO': 3.79},
        '3':  {'VISA': 2.29, 'MASTERCARD': 2.29, 'AMEX': 3.79, 'HYPERCARD': 3.79, 'ELO': 3.79},
        '4':  {'VISA': 2.29, 'MASTERCARD': 2.29, 'AMEX': 3.79, 'HYPERCARD': 3.79, 'ELO': 3.79},
        '5':  {'VISA': 2.29, 'MASTERCARD': 2.29, 'AMEX': 3.79, 'HYPERCARD': 3.79, 'ELO': 3.79},
        '6':  {'VISA': 2.29, 'MASTERCARD': 2.29, 'AMEX': 3.79, 'HYPERCARD': 3.79, 'ELO': 3.79},
        '7':  {'VISA': 2.65, 'MASTERCARD': 2.65, 'AMEX': 4.15, 'HYPERCARD': 4.15, 'ELO': 4.15},
        '8':  {'VISA': 2.65, 'MASTERCARD': 2.65, 'AMEX': 4.15, 'HYPERCARD': 4.15, 'ELO': 4.15},
        '9':  {'VISA': 2.65, 'MASTERCARD': 2.65, 'AMEX': 4.15, 'HYPERCARD': 4.15, 'ELO': 4.15},
        '10': {'VISA': 2.65, 'MASTERCARD': 2.65, 'AMEX': 4.15, 'HYPERCARD': 4.15, 'ELO': 4.15},
        '11': {'VISA': 2.65, 'MASTERCARD': 2.65, 'AMEX': 4.15, 'HYPERCARD': 4.15, 'ELO': 4.15},
        '12': {'VISA': 2.65, 'MASTERCARD': 2.65, 'AMEX': 4.15, 'HYPERCARD': 4.15, 'ELO': 4.15},
                 },
    'txs_antecipacao': {
        '1':  {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': 2.49, 'CABAL': 2.49, 'HYPERCARD': 2.49, 'UNIONPAY': 2.49, 'ELO': 2.49},
        '2':  {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': 2.49, 'CABAL': 2.49, 'HYPERCARD': 2.49, 'UNIONPAY': 2.49, 'ELO': 2.49},
        '3':  {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': 2.49, 'CABAL': 2.49, 'HYPERCARD': 2.49, 'UNIONPAY': 2.49, 'ELO': 2.49},
        '4':  {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': 2.49, 'CABAL': 2.49, 'HYPERCARD': 2.49, 'UNIONPAY': 2.49, 'ELO': 2.49},
        '5':  {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': 2.49, 'CABAL': 2.49, 'HYPERCARD': 2.49, 'UNIONPAY': 2.49, 'ELO': 2.49},
        '6':  {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': 2.49, 'CABAL': 2.49, 'HYPERCARD': 2.49, 'UNIONPAY': 2.49, 'ELO': 2.49},
        '7':  {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': 2.49, 'CABAL': 2.49, 'HYPERCARD': 2.49, 'UNIONPAY': 2.49, 'ELO': 2.49},
        '8':  {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': 2.49, 'CABAL': 2.49, 'HYPERCARD': 2.49, 'UNIONPAY': 2.49, 'ELO': 2.49},
        '9':  {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': 2.49, 'CABAL': 2.49, 'HYPERCARD': 2.49, 'UNIONPAY': 2.49, 'ELO': 2.49},
        '10': {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': 2.49, 'CABAL': 2.49, 'HYPERCARD': 2.49, 'UNIONPAY': 2.49, 'ELO': 2.49},
        '11': {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': 2.49, 'CABAL': 2.49, 'HYPERCARD': 2.49, 'UNIONPAY': 2.49, 'ELO': 2.49},
        '12': {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': 2.49, 'CABAL': 2.49, 'HYPERCARD': 2.49, 'UNIONPAY': 2.49, 'ELO': 2.49},
        '13': {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 2.49},
        '14': {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 2.49},
        '15': {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 2.49},
        '16': {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 2.49},
        '17': {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 2.49},
        '18': {'VISA': 2.49, 'MASTERCARD': 2.49, 'AMEX': '*', 'CABAL': '*', 'HYPERCARD': '*', 'UNIONPAY': '*', 'ELO': 2.49},
                 },
       },
                   }

# %%
from datetime import datetime, timedelta

operadora = input('Digite o nome da operadora do cartão: ').upper()

bandeira = input('Digite o nome da bandeira do cartão: ').upper()

data_venda_str = input('Digite a data da venda: dd/mm/aaaa: ')
data_venda = datetime.strptime(data_venda_str, '%d/%m/%Y')

vlr_venda = float(input('Digite o valor da venda:'))

#Na hora de calcular, será preciso acessar o dict e pegar as taxas. E se qtd_parc for type int, dará erro nesse momento.
qtd_parc  = input('Digite a qtde de parcelas:')#qtd_parc é string, ler acima.

data_antec_str = input('Digite a data da antecipação: dd/mm/aaaa:')
data_antec = datetime.strptime(data_antec_str, '%d/%m/%Y')
# Out:
# Digite o nome da operadora do cartão: stone
# Digite o nome da bandeira do cartão: visa
# Digite a data da venda: dd/mm/aaaa: 03/02/2023
# Digite o valor da venda:1569.45
# Digite a qtde de parcelas:4
# Digite a data da antecipação: dd/mm/aaaa:04/02/2023

# %%
taxa_mdr = taxas_operadoras[operadora]['txs_mdr'][qtd_parc][bandeira]
taxa_antec = taxas_operadoras[operadora]['txs_antecipacao'][qtd_parc][bandeira]
vlr_bruto = (vlr_venda - (vlr_venda * (taxa_mdr/100)))# Valor após MDR
vlr_bruto_parc = vlr_bruto / int(qtd_parc)
lista_parc_final = []
    
if int(qtd_parc) == 1:
    data_futura_p1 = data_venda + timedelta(30)
    qtd_dias_p1 = abs((data_futura_p1 - data_antec).days)
    vlr_final_p1 = vlr_bruto_parc-((qtd_dias_p1*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p1)
        
elif int(qtd_parc) == 2:                        # Timedelta para somar int com data(datetime)
    data_futura_p1 = data_venda + timedelta(30) # Somando 30 dias à data da venda para achar data da 1ª parcela.
    qtd_dias_p1 = abs((data_futura_p1 - data_antec).days)#Através das datas, cálculo de qtd de dias. Abs para conta c/ datas.
    vlr_final_p1 = vlr_bruto_parc-((qtd_dias_p1*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p1)
    
    data_futura_p2 = data_venda + timedelta(60)# Somando 60 dias à data da venda para achar data da 2ª parcela.
    qtd_dias_p2 = abs((data_futura_p2 - data_antec).days)
    vlr_final_p2 = vlr_bruto_parc-((qtd_dias_p2*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p2)
    
elif int(qtd_parc) == 3:                        
    data_futura_p1 = data_venda + timedelta(30) # Somando 30 dias à data da venda para achar data da 1ª parcela.
    qtd_dias_p1 = abs((data_futura_p1 - data_antec).days)#
    vlr_final_p1 = vlr_bruto_parc-((qtd_dias_p1*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p1)
    
    data_futura_p2 = data_venda + timedelta(60)# Somando 60 dias à data da venda para achar data da 2ª parcela.
    qtd_dias_p2 = abs((data_futura_p2 - data_antec).days)
    vlr_final_p2 = vlr_bruto_parc-((qtd_dias_p2*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p2)
    
    data_futura_p3 = data_venda + timedelta(90)# Somando 90 dias à data da venda para achar data da 3ª parcela.
    qtd_dias_p3 = abs((data_futura_p3 - data_antec).days)
    vlr_final_p3 = vlr_bruto_parc-((qtd_dias_p3*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p3)
    
elif int(qtd_parc) == 4:                        
    data_futura_p1 = data_venda + timedelta(30) # Somando 30 dias à data da venda para achar data da 1ª parcela.
    qtd_dias_p1 = abs((data_futura_p1 - data_antec).days)#
    vlr_final_p1 = vlr_bruto_parc-((qtd_dias_p1*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p1)
    
    data_futura_p2 = data_venda + timedelta(60)# Somando 60 dias à data da venda para achar data da 2ª parcela.
    qtd_dias_p2 = abs((data_futura_p2 - data_antec).days)
    vlr_final_p2 = vlr_bruto_parc-((qtd_dias_p2*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p2)
    
    data_futura_p3 = data_venda + timedelta(90)# Somando 90 dias à data da venda para achar data da 3ª parcela.
    qtd_dias_p3 = abs((data_futura_p3 - data_antec).days)
    vlr_final_p3 = vlr_bruto_parc-((qtd_dias_p3*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p3)
    
    data_futura_p4 = data_venda + timedelta(120)# Somando 120 dias à data da venda para achar data da 4ª parcela.
    qtd_dias_p4 = abs((data_futura_p4 - data_antec).days)
    vlr_final_p4 = vlr_bruto_parc-((qtd_dias_p4*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p4)
    
elif int(qtd_parc) == 5:                        
    data_futura_p1 = data_venda + timedelta(30) # Somando 30 dias à data da venda para achar data da 1ª parcela.
    qtd_dias_p1 = abs((data_futura_p1 - data_antec).days)#
    vlr_final_p1 = vlr_bruto_parc-((qtd_dias_p1*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p1)
    
    data_futura_p2 = data_venda + timedelta(60)# Somando 60 dias à data da venda para achar data da 2ª parcela.
    qtd_dias_p2 = abs((data_futura_p2 - data_antec).days)
    vlr_final_p2 = vlr_bruto_parc-((qtd_dias_p2*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p2)
    
    data_futura_p3 = data_venda + timedelta(90)# Somando 90 dias à data da venda para achar data da 3ª parcela.
    qtd_dias_p3 = abs((data_futura_p3 - data_antec).days)
    vlr_final_p3 = vlr_bruto_parc-((qtd_dias_p3*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p3)
    
    data_futura_p4 = data_venda + timedelta(120)# Somando 120 dias à data da venda para achar data da 4ª parcela.
    qtd_dias_p4 = abs((data_futura_p4 - data_antec).days)
    vlr_final_p4 = vlr_bruto_parc-((qtd_dias_p4*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p4)
    
    data_futura_p5 = data_venda + timedelta(150)# Somando 150 dias à data da venda para achar data da 5ª parcela.
    qtd_dias_p5 = abs((data_futura_p5 - data_antec).days)
    vlr_final_p5 = vlr_bruto_parc-((qtd_dias_p5*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p5)
    
elif int(qtd_parc) == 6:                        
    data_futura_p1 = data_venda + timedelta(30) # Somando 30 dias à data da venda para achar data da 1ª parcela.
    qtd_dias_p1 = abs((data_futura_p1 - data_antec).days)#
    vlr_final_p1 = vlr_bruto_parc-((qtd_dias_p1*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p1)
    
    data_futura_p2 = data_venda + timedelta(60)# Somando 60 dias à data da venda para achar data da 2ª parcela.
    qtd_dias_p2 = abs((data_futura_p2 - data_antec).days)
    vlr_final_p2 = vlr_bruto_parc-((qtd_dias_p2*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p2)
    
    data_futura_p3 = data_venda + timedelta(90)# Somando 90 dias à data da venda para achar data da 3ª parcela.
    qtd_dias_p3 = abs((data_futura_p3 - data_antec).days)
    vlr_final_p3 = vlr_bruto_parc-((qtd_dias_p3*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p3)
    
    data_futura_p4 = data_venda + timedelta(120)# Somando 120 dias à data da venda para achar data da 4ª parcela.
    qtd_dias_p4 = abs((data_futura_p4 - data_antec).days)
    vlr_final_p4 = vlr_bruto_parc-((qtd_dias_p4*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p4)
    
    data_futura_p5 = data_venda + timedelta(150)# Somando 150 dias à data da venda para achar data da 5ª parcela.
    qtd_dias_p5 = abs((data_futura_p5 - data_antec).days)
    vlr_final_p5 = vlr_bruto_parc-((qtd_dias_p5*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p5)
    
    data_futura_p6 = data_venda + timedelta(180)# Somando 180 dias à data da venda para achar data da 6ª parcela.
    qtd_dias_p6 = abs((data_futura_p6 - data_antec).days)
    vlr_final_p6 = vlr_bruto_parc-((qtd_dias_p6*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p6)
    
elif int(qtd_parc) == 7:                        
    data_futura_p1 = data_venda + timedelta(30) # Somando 30 dias à data da venda para achar data da 1ª parcela.
    qtd_dias_p1 = abs((data_futura_p1 - data_antec).days)#
    vlr_final_p1 = vlr_bruto_parc-((qtd_dias_p1*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p1)
    
    data_futura_p2 = data_venda + timedelta(60)# Somando 60 dias à data da venda para achar data da 2ª parcela.
    qtd_dias_p2 = abs((data_futura_p2 - data_antec).days)
    vlr_final_p2 = vlr_bruto_parc-((qtd_dias_p2*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p2)
    
    data_futura_p3 = data_venda + timedelta(90)# Somando 90 dias à data da venda para achar data da 3ª parcela.
    qtd_dias_p3 = abs((data_futura_p3 - data_antec).days)
    vlr_final_p3 = vlr_bruto_parc-((qtd_dias_p3*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p3)
    
    data_futura_p4 = data_venda + timedelta(120)# Somando 120 dias à data da venda para achar data da 4ª parcela.
    qtd_dias_p4 = abs((data_futura_p4 - data_antec).days)
    vlr_final_p4 = vlr_bruto_parc-((qtd_dias_p4*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p4)
    
    data_futura_p5 = data_venda + timedelta(150)# Somando 150 dias à data da venda para achar data da 5ª parcela.
    qtd_dias_p5 = abs((data_futura_p5 - data_antec).days)
    vlr_final_p5 = vlr_bruto_parc-((qtd_dias_p5*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p5)
    
    data_futura_p6 = data_venda + timedelta(180)# Somando 180 dias à data da venda para achar data da 6ª parcela.
    qtd_dias_p6 = abs((data_futura_p6 - data_antec).days)
    vlr_final_p6 = vlr_bruto_parc-((qtd_dias_p6*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p6)
    
    data_futura_p7 = data_venda + timedelta(210)# Somando 210 dias à data da venda para achar data da 7ª parcela.
    qtd_dias_p7 = abs((data_futura_p7 - data_antec).days)
    vlr_final_p7 = vlr_bruto_parc-((qtd_dias_p7*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p7)
    
elif int(qtd_parc) == 8:                        
    data_futura_p1 = data_venda + timedelta(30) # Somando 30 dias à data da venda para achar data da 1ª parcela.
    qtd_dias_p1 = abs((data_futura_p1 - data_antec).days)#
    vlr_final_p1 = vlr_bruto_parc-((qtd_dias_p1*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p1)
    
    data_futura_p2 = data_venda + timedelta(60)# Somando 60 dias à data da venda para achar data da 2ª parcela.
    qtd_dias_p2 = abs((data_futura_p2 - data_antec).days)
    vlr_final_p2 = vlr_bruto_parc-((qtd_dias_p2*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p2)
    
    data_futura_p3 = data_venda + timedelta(90)# Somando 90 dias à data da venda para achar data da 3ª parcela.
    qtd_dias_p3 = abs((data_futura_p3 - data_antec).days)
    vlr_final_p3 = vlr_bruto_parc-((qtd_dias_p3*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p3)
    
    data_futura_p4 = data_venda + timedelta(120)# Somando 120 dias à data da venda para achar data da 4ª parcela.
    qtd_dias_p4 = abs((data_futura_p4 - data_antec).days)
    vlr_final_p4 = vlr_bruto_parc-((qtd_dias_p4*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p4)
    
    data_futura_p5 = data_venda + timedelta(150)# Somando 150 dias à data da venda para achar data da 5ª parcela.
    qtd_dias_p5 = abs((data_futura_p5 - data_antec).days)
    vlr_final_p5 = vlr_bruto_parc-((qtd_dias_p5*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p5)
    
    data_futura_p6 = data_venda + timedelta(180)# Somando 180 dias à data da venda para achar data da 6ª parcela.
    qtd_dias_p6 = abs((data_futura_p6 - data_antec).days)
    vlr_final_p6 = vlr_bruto_parc-((qtd_dias_p6*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p6)
    
    data_futura_p7 = data_venda + timedelta(210)# Somando 210 dias à data da venda para achar data da 7ª parcela.
    qtd_dias_p7 = abs((data_futura_p7 - data_antec).days)
    vlr_final_p7 = vlr_bruto_parc-((qtd_dias_p7*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p7)
    
    data_futura_p8 = data_venda + timedelta(240)# Somando 240 dias à data da venda para achar data da 8ª parcela.
    qtd_dias_p8 = abs((data_futura_p8 - data_antec).days)
    vlr_final_p8 = vlr_bruto_parc-((qtd_dias_p8*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p8)

elif int(qtd_parc) == 9:                        
    data_futura_p1 = data_venda + timedelta(30) # Somando 30 dias à data da venda para achar data da 1ª parcela.
    qtd_dias_p1 = abs((data_futura_p1 - data_antec).days)#
    vlr_final_p1 = vlr_bruto_parc-((qtd_dias_p1*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p1)
    
    data_futura_p2 = data_venda + timedelta(60)# Somando 60 dias à data da venda para achar data da 2ª parcela.
    qtd_dias_p2 = abs((data_futura_p2 - data_antec).days)
    vlr_final_p2 = vlr_bruto_parc-((qtd_dias_p2*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p2)
    
    data_futura_p3 = data_venda + timedelta(90)# Somando 90 dias à data da venda para achar data da 3ª parcela.
    qtd_dias_p3 = abs((data_futura_p3 - data_antec).days)
    vlr_final_p3 = vlr_bruto_parc-((qtd_dias_p3*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p3)
    
    data_futura_p4 = data_venda + timedelta(120)# Somando 120 dias à data da venda para achar data da 4ª parcela.
    qtd_dias_p4 = abs((data_futura_p4 - data_antec).days)
    vlr_final_p4 = vlr_bruto_parc-((qtd_dias_p4*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p4)
    
    data_futura_p5 = data_venda + timedelta(150)# Somando 150 dias à data da venda para achar data da 5ª parcela.
    qtd_dias_p5 = abs((data_futura_p5 - data_antec).days)
    vlr_final_p5 = vlr_bruto_parc-((qtd_dias_p5*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p5)
    
    data_futura_p6 = data_venda + timedelta(180)# Somando 180 dias à data da venda para achar data da 6ª parcela.
    qtd_dias_p6 = abs((data_futura_p6 - data_antec).days)
    vlr_final_p6 = vlr_bruto_parc-((qtd_dias_p6*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p6)
    
    data_futura_p7 = data_venda + timedelta(210)# Somando 210 dias à data da venda para achar data da 7ª parcela.
    qtd_dias_p7 = abs((data_futura_p7 - data_antec).days)
    vlr_final_p7 = vlr_bruto_parc-((qtd_dias_p7*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p7)
    
    data_futura_p8 = data_venda + timedelta(240)# Somando 240 dias à data da venda para achar data da 8ª parcela.
    qtd_dias_p8 = abs((data_futura_p8 - data_antec).days)
    vlr_final_p8 = vlr_bruto_parc-((qtd_dias_p8*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p8)
    
    data_futura_p9 = data_venda + timedelta(270)# Somando 270 dias à data da venda para achar data da 9ª parcela.
    qtd_dias_p9 = abs((data_futura_p9 - data_antec).days)
    vlr_final_p9 = vlr_bruto_parc-((qtd_dias_p9*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p9)
    
elif int(qtd_parc) == 10:                        
    data_futura_p1 = data_venda + timedelta(30) # Somando 30 dias à data da venda para achar data da 1ª parcela.
    qtd_dias_p1 = abs((data_futura_p1 - data_antec).days)#
    vlr_final_p1 = vlr_bruto_parc-((qtd_dias_p1*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p1)
    
    data_futura_p2 = data_venda + timedelta(60)# Somando 60 dias à data da venda para achar data da 2ª parcela.
    qtd_dias_p2 = abs((data_futura_p2 - data_antec).days)
    vlr_final_p2 = vlr_bruto_parc-((qtd_dias_p2*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p2)
    
    data_futura_p3 = data_venda + timedelta(90)# Somando 90 dias à data da venda para achar data da 3ª parcela.
    qtd_dias_p3 = abs((data_futura_p3 - data_antec).days)
    vlr_final_p3 = vlr_bruto_parc-((qtd_dias_p3*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p3)
    
    data_futura_p4 = data_venda + timedelta(120)# Somando 120 dias à data da venda para achar data da 4ª parcela.
    qtd_dias_p4 = abs((data_futura_p4 - data_antec).days)
    vlr_final_p4 = vlr_bruto_parc-((qtd_dias_p4*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p4)
    
    data_futura_p5 = data_venda + timedelta(150)# Somando 150 dias à data da venda para achar data da 5ª parcela.
    qtd_dias_p5 = abs((data_futura_p5 - data_antec).days)
    vlr_final_p5 = vlr_bruto_parc-((qtd_dias_p5*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p5)
    
    data_futura_p6 = data_venda + timedelta(180)# Somando 180 dias à data da venda para achar data da 6ª parcela.
    qtd_dias_p6 = abs((data_futura_p6 - data_antec).days)
    vlr_final_p6 = vlr_bruto_parc-((qtd_dias_p6*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p6)
    
    data_futura_p7 = data_venda + timedelta(210)# Somando 210 dias à data da venda para achar data da 7ª parcela.
    qtd_dias_p7 = abs((data_futura_p7 - data_antec).days)
    vlr_final_p7 = vlr_bruto_parc-((qtd_dias_p7*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p7)
    
    data_futura_p8 = data_venda + timedelta(240)# Somando 240 dias à data da venda para achar data da 8ª parcela.
    qtd_dias_p8 = abs((data_futura_p8 - data_antec).days)
    vlr_final_p8 = vlr_bruto_parc-((qtd_dias_p8*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p8)
    
    data_futura_p9 = data_venda + timedelta(270)# Somando 270 dias à data da venda para achar data da 9ª parcela.
    qtd_dias_p9 = abs((data_futura_p9 - data_antec).days)
    vlr_final_p9 = vlr_bruto_parc-((qtd_dias_p9*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p9)
    
    data_futura_p10 = data_venda + timedelta(300) # Somando 300 dias à data da venda para achar data da 10ª parcela.
    qtd_dias_p10 = abs((data_futura_p10 - data_antec).days)
    vlr_final_p10 = vlr_bruto_parc-((qtd_dias_p10*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p10)

elif int(qtd_parc) == 11:                        
    data_futura_p1 = data_venda + timedelta(30) # Somando 30 dias à data da venda para achar data da 1ª parcela.
    qtd_dias_p1 = abs((data_futura_p1 - data_antec).days)#
    vlr_final_p1 = vlr_bruto_parc-((qtd_dias_p1*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p1)
    
    data_futura_p2 = data_venda + timedelta(60)# Somando 60 dias à data da venda para achar data da 2ª parcela.
    qtd_dias_p2 = abs((data_futura_p2 - data_antec).days)
    vlr_final_p2 = vlr_bruto_parc-((qtd_dias_p2*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p2)
    
    data_futura_p3 = data_venda + timedelta(90)# Somando 90 dias à data da venda para achar data da 3ª parcela.
    qtd_dias_p3 = abs((data_futura_p3 - data_antec).days)
    vlr_final_p3 = vlr_bruto_parc-((qtd_dias_p3*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p3)
    
    data_futura_p4 = data_venda + timedelta(120)# Somando 120 dias à data da venda para achar data da 4ª parcela.
    qtd_dias_p4 = abs((data_futura_p4 - data_antec).days)
    vlr_final_p4 = vlr_bruto_parc-((qtd_dias_p4*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p4)
    
    data_futura_p5 = data_venda + timedelta(150)# Somando 150 dias à data da venda para achar data da 5ª parcela.
    qtd_dias_p5 = abs((data_futura_p5 - data_antec).days)
    vlr_final_p5 = vlr_bruto_parc-((qtd_dias_p5*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p5)
    
    data_futura_p6 = data_venda + timedelta(180)# Somando 180 dias à data da venda para achar data da 6ª parcela.
    qtd_dias_p6 = abs((data_futura_p6 - data_antec).days)
    vlr_final_p6 = vlr_bruto_parc-((qtd_dias_p6*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p6)
    
    data_futura_p7 = data_venda + timedelta(210)# Somando 210 dias à data da venda para achar data da 7ª parcela.
    qtd_dias_p7 = abs((data_futura_p7 - data_antec).days)
    vlr_final_p7 = vlr_bruto_parc-((qtd_dias_p7*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p7)
    
    data_futura_p8 = data_venda + timedelta(240)# Somando 240 dias à data da venda para achar data da 8ª parcela.
    qtd_dias_p8 = abs((data_futura_p8 - data_antec).days)
    vlr_final_p8 = vlr_bruto_parc-((qtd_dias_p8*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p8)
    
    data_futura_p9 = data_venda + timedelta(270)# Somando 270 dias à data da venda para achar data da 9ª parcela.
    qtd_dias_p9 = abs((data_futura_p9 - data_antec).days)
    vlr_final_p9 = vlr_bruto_parc-((qtd_dias_p9*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p9)
    
    data_futura_p10 = data_venda + timedelta(300) # Somando 300 dias à data da venda para achar data da 10ª parcela.
    qtd_dias_p10 = abs((data_futura_p10 - data_antec).days)
    vlr_final_p10 = vlr_bruto_parc-((qtd_dias_p10*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p10)
    
    data_futura_p11 = data_venda + timedelta(330) # Somando 330 dias à data da venda para achar data da 11ª parcela.
    qtd_dias_p11 = abs((data_futura_p11 - data_antec).days)
    vlr_final_p11 = vlr_bruto_parc-((qtd_dias_p11*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p11)
    
elif int(qtd_parc) == 12:                        
    data_futura_p1 = data_venda + timedelta(30) # Somando 30 dias à data da venda para achar data da 1ª parcela.
    qtd_dias_p1 = abs((data_futura_p1 - data_antec).days)#
    vlr_final_p1 = vlr_bruto_parc-((qtd_dias_p1*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p1)
    
    data_futura_p2 = data_venda + timedelta(60)# Somando 60 dias à data da venda para achar data da 2ª parcela.
    qtd_dias_p2 = abs((data_futura_p2 - data_antec).days)
    vlr_final_p2 = vlr_bruto_parc-((qtd_dias_p2*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p2)
    
    data_futura_p3 = data_venda + timedelta(90)# Somando 90 dias à data da venda para achar data da 3ª parcela.
    qtd_dias_p3 = abs((data_futura_p3 - data_antec).days)
    vlr_final_p3 = vlr_bruto_parc-((qtd_dias_p3*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p3)
    
    data_futura_p4 = data_venda + timedelta(120)# Somando 120 dias à data da venda para achar data da 4ª parcela.
    qtd_dias_p4 = abs((data_futura_p4 - data_antec).days)
    vlr_final_p4 = vlr_bruto_parc-((qtd_dias_p4*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p4)
    
    data_futura_p5 = data_venda + timedelta(150)# Somando 150 dias à data da venda para achar data da 5ª parcela.
    qtd_dias_p5 = abs((data_futura_p5 - data_antec).days)
    vlr_final_p5 = vlr_bruto_parc-((qtd_dias_p5*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p5)
    
    data_futura_p6 = data_venda + timedelta(180)# Somando 180 dias à data da venda para achar data da 6ª parcela.
    qtd_dias_p6 = abs((data_futura_p6 - data_antec).days)
    vlr_final_p6 = vlr_bruto_parc-((qtd_dias_p6*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p6)
    
    data_futura_p7 = data_venda + timedelta(210)# Somando 210 dias à data da venda para achar data da 7ª parcela.
    qtd_dias_p7 = abs((data_futura_p7 - data_antec).days)
    vlr_final_p7 = vlr_bruto_parc-((qtd_dias_p7*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p7)
    
    data_futura_p8 = data_venda + timedelta(240)# Somando 240 dias à data da venda para achar data da 8ª parcela.
    qtd_dias_p8 = abs((data_futura_p8 - data_antec).days)
    vlr_final_p8 = vlr_bruto_parc-((qtd_dias_p8*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p8)
    
    data_futura_p9 = data_venda + timedelta(270)# Somando 270 dias à data da venda para achar data da 9ª parcela.
    qtd_dias_p9 = abs((data_futura_p9 - data_antec).days)
    vlr_final_p9 = vlr_bruto_parc-((qtd_dias_p9*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p9)
    
    data_futura_p10 = data_venda + timedelta(300) # Somando 300 dias à data da venda para achar data da 10ª parcela.
    qtd_dias_p10 = abs((data_futura_p10 - data_antec).days)
    vlr_final_p10 = vlr_bruto_parc-((qtd_dias_p10*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p10)
    
    data_futura_p11 = data_venda + timedelta(330) # Somando 330 dias à data da venda para achar data da 11ª parcela.
    qtd_dias_p11 = abs((data_futura_p11 - data_antec).days)
    vlr_final_p11 = vlr_bruto_parc-((qtd_dias_p11*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p11)
    
    data_futura_p12 = data_venda + timedelta(360) # Somando 360 dias à data da venda para achar data da 12ª parcela.
    qtd_dias_p12 = abs((data_futura_p12 - data_antec).days)
    vlr_final_p12 = vlr_bruto_parc-((qtd_dias_p12*(timedelta(taxa_antec/100)/timedelta(30)*vlr_bruto_parc)))
    lista_parc_final.append(vlr_final_p12)
                        
# Se necessário, acrescentar mais parcelas conforme padrão acima. 
# Copiar todo o elif anterior e colar. Copiar as 4 linhas da última parcela e acrescentar mais uma, alterando o núm da parcela.    
    
print('INFORMAÇÕES DO CARTÃO DE CRÉDITO')
print(f'Operadora: {operadora}')
print(f'Bandeira: {bandeira}')
print()
print('INFORMAÇÕES DA VENDA')
print(f'Data da Venda: {data_venda_str}')
print(f'Valor da Venda: {vlr_venda:,.2f}')
print(f'Quantidade de Parcelas: {qtd_parc}')
print()
print('INFORMAÇÕES DA TAXA DE ADMINISTRAÇÃO')
print(f'Valor da Taxa de Administração: {vlr_venda-vlr_bruto:,.2f} - Percentual: {taxa_mdr/100:,.2%}')
print(f'Saldo Total Bruto: {vlr_bruto:,.2f}')
print(f'Valor Bruto de Cada Parcela: {vlr_bruto_parc:,.2f}')
print()
print('INFORMAÇÕES DA TAXA DE ANTECIPAÇÃO')    
print(f'Data da Antecipação: {data_antec_str}')
print(f'Valor da Taxa de Antecipação: R$ {vlr_bruto-sum(lista_parc_final):,.2f} - Percentual: {taxa_antec/100:,.2%} A.M.')
print(f'Saldo Final: R$ {sum(lista_parc_final):,.2f}')
# Out:
# INFORMAÇÕES DO CARTÃO DE CRÉDITO
# Operadora: STONE
# Bandeira: VISA
#
# INFORMAÇÕES DA VENDA
# Data da Venda: 03/02/2023
# Valor da Venda: 1,569.45
# Quantidade de Parcelas: 4
#
# INFORMAÇÕES DA TAXA DE ADMINISTRAÇÃO
# Valor da Taxa de Administração: 40.65 - Percentual: 2.59%
# Saldo Total Bruto: 1,528.80
# Valor Bruto de Cada Parcela: 382.20
#
# INFORMAÇÕES DA TAXA DE ANTECIPAÇÃO
# Data da Antecipação: 04/02/2023
# Valor da Taxa de Antecipação: R$ 69.76 - Percentual: 1.85% A.M.
# Saldo Final: R$ 1,459.04
